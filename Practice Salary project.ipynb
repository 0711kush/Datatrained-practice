# %% [markdown]
# # Salary Project

# %%
import pandas as pd
df=pd.read_csv('salaries.csv')
df
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'yrs.since.phd', 'yrs.service', 'sex', 'salary'], dtype='object')

# %% [markdown]
# # About the columns
#     1.Rank
#         This column shows at which post the person is curently working.
#     2.Discipline
#         This grade significantly shows how much the person is dedicated to his/her work.
#     3.yrs.since.phd
#         This duration is counted according to the years the person has help his/her Phd degree.
#     4.yrs.service
#         This duration is counted on the basis of how much years the person is being working.
#     5.Sex
#         This column indicates the gender of the person.
#     6.Salary
#         This column is the salary column and our target column as well.

# %%
df.head()
# Out:
#        rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0      Prof          B             19           18  Male  139750
# 1      Prof          B             20           16  Male  173200
# 2  AsstProf          B              4            3  Male   79750
# 3      Prof          B             45           39  Male  115000
# 4      Prof          B             40           41  Male  141500

# %%
df.head(10)
# Out:
#         rank discipline  yrs.since.phd  yrs.service     sex  salary
# 0       Prof          B             19           18    Male  139750
# 1       Prof          B             20           16    Male  173200
# 2   AsstProf          B              4            3    Male   79750
# 3       Prof          B             45           39    Male  115000
# 4       Prof          B             40           41    Male  141500
# 5  AssocProf          B              6            6    Male   97000
# 6       Prof          B             30           23    Male  175000
# 7       Prof          B             45           45    Male  147765
# 8       Prof          B             21           20    Male  119250
# 9       Prof          B             18           18  Female  129000

# %%
df.tail()
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035

# %%
df.tail(10)
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 387      Prof          A             29           15  Male  109305
# 388      Prof          A             38           36  Male  119450
# 389      Prof          A             33           18  Male  186023
# 390      Prof          A             40           19  Male  166605
# 391      Prof          A             30           19  Male  151292
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035

# %%
df.sample()
# Out:
#           rank discipline  yrs.since.phd  yrs.service   sex  salary
# 379  AssocProf          A             11            8  Male  104121

# %%
df.sample(5)
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 78   AsstProf          B              3            1  Male   86100
# 228      Prof          A             16           11  Male   88175
# 205      Prof          B             21            2  Male   96545
# 1        Prof          B             20           16  Male  173200
# 185      Prof          B             33           30  Male  134000

# %%
df.sample(3)
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 38       Prof          B             41           31  Male  125196
# 335      Prof          B             36           38  Male  151445
# 164  AsstProf          B              1            0  Male   88795

# %%
df.shape
# Out:
# (397, 6)

# %%
df.isnull()
# Out:
#       rank  discipline  yrs.since.phd  yrs.service    sex  salary
# 0    False       False          False        False  False   False
# 1    False       False          False        False  False   False
# 2    False       False          False        False  False   False
# 3    False       False          False        False  False   False
# 4    False       False          False        False  False   False
# ..     ...         ...            ...          ...    ...     ...
# 392  False       False          False        False  False   False
# 393  False       False          False        False  False   False
# 394  False       False          False        False  False   False
# 395  False       False          False        False  False   False
# 396  False       False          False        False  False   False
#
# [397 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# rank             0
# discipline       0
# yrs.since.phd    0
# yrs.service      0
# sex              0
# salary           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  397 non-null    int64
#  3   yrs.service    397 non-null    int64
#  4   sex            397 non-null    object
#  5   salary         397 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 18.7+ KB

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()

list1=['rank','discipline','sex']
for i in list1:
    df[i]=le.fit_transform(df[i].astype(str))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    int32
#  1   discipline     397 non-null    int32
#  2   yrs.since.phd  397 non-null    int64
#  3   yrs.service    397 non-null    int64
#  4   sex            397 non-null    int32
#  5   salary         397 non-null    int64
# dtypes: int32(3), int64(3)
# memory usage: 14.1 KB

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(df['rank'],df['salary'])
# Out:
# <AxesSubplot:xlabel='rank', ylabel='salary'>

# %%
sns.scatterplot(df['discipline'],df['salary'])
# Out:
# <AxesSubplot:xlabel='discipline', ylabel='salary'>

# %%
sns.scatterplot(df['yrs.since.phd'],df['salary'])
# Out:
# <AxesSubplot:xlabel='yrs.since.phd', ylabel='salary'>

# %%
sns.scatterplot(df['yrs.service'],df['salary'])
# Out:
# <AxesSubplot:xlabel='yrs.service', ylabel='salary'>

# %%
sns.scatterplot(df['sex'],df['salary'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='salary'>

# %%
sns.pairplot(df)

# %%
sns.distplot(df['rank'])
# Out:
# <AxesSubplot:xlabel='rank', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalised.The building blocks is out of the normalised curve.
#
# This plot has 3 modes(most occuring freq)

# %%
sns.distplot(df['yrs.service'])
# Out:
# <AxesSubplot:xlabel='yrs.service', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalised.The building blocks is out of the normalised curve.
#
# This plot is almost bimodal i.e, 2 modes(most occuring freq)

# %%
sns.distplot(df['yrs.since.phd'])
# Out:
# <AxesSubplot:xlabel='yrs.since.phd', ylabel='Density'>

# %%
sns.distplot(df['sex'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalised.The building blocks is out of the normalised curve.
#
# This plot is almost bimodal i.e, 2 modes(most occuring freq)

# %%
sns.distplot(df['salary'])
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %%
df.head(10)
# Out:
#    rank  discipline  yrs.since.phd  yrs.service  sex  salary
# 0     2           1             19           18    1  139750
# 1     2           1             20           16    1  173200
# 2     1           1              4            3    1   79750
# 3     2           1             45           39    1  115000
# 4     2           1             40           41    1  141500
# 5     0           1              6            6    1   97000
# 6     2           1             30           23    1  175000
# 7     2           1             45           45    1  147765
# 8     2           1             21           20    1  119250
# 9     2           1             18           18    0  129000

# %%
sns.pairplot(df)

# %%
df.skew()
# Out:
# rank            -1.151164
# discipline      -0.177684
# yrs.since.phd    0.300880
# yrs.service      0.650569
# sex             -2.709958
# salary           0.714568
# dtype: float64

# %% [markdown]
# there is a skewness in the rank and sex column

# %%
df.plot(kind='kde',subplots=True,layout=(2,3),figsize=(20,20))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %% [markdown]
# we are not getting any beneficial information from this

# %%
df.plot(kind='box',subplots=True,layout=(2,3),figsize=(20,20))
# Out:
# rank                AxesSubplot(0.125,0.536818;0.227941x0.343182)
# discipline       AxesSubplot(0.398529,0.536818;0.227941x0.343182)
# yrs.since.phd    AxesSubplot(0.672059,0.536818;0.227941x0.343182)
# yrs.service            AxesSubplot(0.125,0.125;0.227941x0.343182)
# sex                 AxesSubplot(0.398529,0.125;0.227941x0.343182)
# salary              AxesSubplot(0.672059,0.125;0.227941x0.343182)
# dtype: object

# %% [markdown]
# this shows there are very less outliers in the data

# %%
df.plot(kind='hist',subplots=True,layout=(2,3),figsize=(20,20))
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>]], dtype=object)

# %%
df.describe()
# Out:
#              rank  discipline  yrs.since.phd  yrs.service         sex  \
# count  397.000000  397.000000     397.000000   397.000000  397.000000
# mean     1.508816    0.544081      22.314861    17.614610    0.901763
# std      0.757486    0.498682      12.887003    13.006024    0.298010
# min      0.000000    0.000000       1.000000     0.000000    0.000000
# 25%      1.000000    0.000000      12.000000     7.000000    1.000000
# 50%      2.000000    1.000000      21.000000    16.000000    1.000000
# 75%      2.000000    1.000000      32.000000    27.000000    1.000000
# max      2.000000    1.000000      56.000000    60.000000    1.000000
#
#               salary
# count     397.000000
# mean   113706.458438
# std     30289.038695
# min     57800.000000
# 25%     91000.000000
# 50%    107300.000000
# 75%    134185.000000
# max    231545.000000

# %%
# we can also transpose this matrix if the number of column incresases
round(df.describe()[1:].transpose(),2)
# Out:
#                     mean       std      min      25%       50%       75%  \
# rank                1.51      0.76      0.0      1.0       2.0       2.0
# discipline          0.54      0.50      0.0      0.0       1.0       1.0
# yrs.since.phd      22.31     12.89      1.0     12.0      21.0      32.0
# yrs.service        17.61     13.01      0.0      7.0      16.0      27.0
# sex                 0.90      0.30      0.0      1.0       1.0       1.0
# salary         113706.46  30289.04  57800.0  91000.0  107300.0  134185.0
#
#                     max
# rank                2.0
# discipline          1.0
# yrs.since.phd      56.0
# yrs.service        60.0
# sex                 1.0
# salary         231545.0

# %%
plt.figure(figsize=(10,10))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=1,annot=True,fmt="f")
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title("Variables summary")
plt.savefig('heatmap.png')
plt.show()

# %% [markdown]
# # Outcome of describe of datasets:
# From the above plotting we are determining mean, standard deviation, minimum and maximum value of each column. It helps us further in data cleaning.
#
# Total Number of rows in the datasets:
# 1. 397 rows
# 2. 5 columns
#
# Rank:
# 1. Mean=1.508816
# 2. std= 0.757486
# 3. max_value=2.000000
# 4. min_value=0
#
# Discipline:
# 1. Mean=0.544081
# 2. std=0.498682
# 3. max_value=1.000000
# 4. min_value=0
#
# Years since Phd:
# 1. Mean=22.314861
# 2. std = 12.887003
# 3. max_value=56.000000
# 4. min_value=1.000000
#
# Years of service:
# 1. Mean=17.614610
# 2. std= 13.006024
# 3. max_value=60.000000
# 4. min_value=0
#
# Sex	:
# 1. Mean=0.901763
# 2. std=0.298010
# 3. max_value=1.000000
# 4. min_value=0

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#          rank  discipline  yrs.since.phd  yrs.service       sex    salary
# 0    0.649257    0.915403       0.257550     0.029669  0.330058  0.860919
# 1    0.649257    0.915403       0.179854     0.124300  0.330058  1.966672
# 2    0.672564    0.915403       1.422982     1.125098  0.330058  1.122495
# 3    0.649257    0.915403       1.762533     1.646343  0.330058  0.042760
# 4    0.649257    0.915403       1.374055     1.800312  0.330058  0.918768
# ..        ...         ...            ...          ...       ...       ...
# 392  0.649257    1.092415       0.830187     0.953483  0.330058  0.350418
# 393  0.649257    1.092415       0.674796     0.106654  0.330058  1.218396
# 394  0.649257    1.092415       1.529446     0.568560  0.330058  0.395640
# 395  0.649257    1.092415       0.208623     0.201284  0.330058  0.607502
# 396  0.672564    1.092415       1.112200     1.048113  0.330058  1.080017
#
# [397 rows x 6 columns]

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  9,  19,  24,  34,  35,  43,  47,  48,  52,  63,  68,  84,  90,
#        103, 114, 119, 123, 127, 131, 132, 133, 148, 153, 179, 186, 218,
#        230, 231, 233, 237, 245, 253, 254, 274, 316, 323, 330, 332, 334,
#        341, 358, 361, 364], dtype=int64), array([4, 4, 4, 4, 4, 5, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 3, 4, 4, 4,
#        4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 3, 4, 4, 4, 4, 4, 5],
#       dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)] #removing outliers

# %%
df=df_new
df.shape
# Out:
# (354, 6)

# %% [markdown]
# Now the outliers are removed from the data

# %% [markdown]
# it shows that there are outliers present in yrs.service & salary column

# %%
c1=df.corr()
c1
# Out:
#                    rank  discipline  yrs.since.phd  yrs.service  sex    salary
# rank           1.000000   -0.095962       0.524310     0.446604  NaN  0.515398
# discipline    -0.095962    1.000000      -0.233685    -0.185759  NaN  0.127542
# yrs.since.phd  0.524310   -0.233685       1.000000     0.908046  NaN  0.386818
# yrs.service    0.446604   -0.185759       0.908046     1.000000  NaN  0.284771
# sex                 NaN         NaN            NaN          NaN  NaN       NaN
# salary         0.515398    0.127542       0.386818     0.284771  NaN  1.000000

# %%
sns.heatmap(c1,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# this implies sex doesn't affect the salary outcome so we can remove this from the data

# %%
plt.figure(figsize=(15,7))
sns.heatmap(c1, annot= True, linewidths = 0.5, linecolor = "black")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,7))
sns.heatmap(c1, annot= True, linewidths = 0.5, linecolor = "black", fmt = ".2f")
# Out:
# <AxesSubplot:>

# %%
c1['salary'].sort_values()
# Out:
# discipline       0.127542
# yrs.service      0.284771
# yrs.since.phd    0.386818
# rank             0.515398
# salary           1.000000
# sex                   NaN
# Name: salary, dtype: float64

# %% [markdown]
# Here,we are setting threshold of correlation as +/- 0.1. It is not standard. The dataset demands.

# %%
df.drop('sex',axis=1,inplace=True)
df.head()
# Out:
#    rank  discipline  yrs.since.phd  yrs.service  salary
# 0     2           1             19           18  139750
# 1     2           1             20           16  173200
# 2     1           1              4            3   79750
# 3     2           1             45           39  115000
# 4     2           1             40           41  141500

# %% [markdown]
# # Seperate the data

# %%
#independent column
x=df_new.iloc[:,:-1]
x
# Out:
#      rank  discipline  yrs.since.phd  yrs.service
# 0       2           1             19           18
# 1       2           1             20           16
# 2       1           1              4            3
# 3       2           1             45           39
# 4       2           1             40           41
# ..    ...         ...            ...          ...
# 392     2           0             33           30
# 393     2           0             31           19
# 394     2           0             42           25
# 395     2           0             25           15
# 396     1           0              8            4
#
# [354 rows x 4 columns]

# %%
#dependent column
y=df_new.iloc[:,-1]
y
# Out:
# 0      139750
# 1      173200
# 2       79750
# 3      115000
# 4      141500
#         ...
# 392    103106
# 393    150564
# 394    101738
# 395     95329
# 396     81035
# Name: salary, Length: 354, dtype: int64

# %% [markdown]
# # Transforming data to remove skewness:

# %%
from sklearn.preprocessing import power_transform

# %%
x = power_transform(x,method='yeo-johnson')

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x
# Out:
# array([[ 0.66261867,  0.9133438 , -0.16993349,  0.21391071],
#        [ 0.66261867,  0.9133438 , -0.09133723,  0.06567291],
#        [-1.18533666,  0.9133438 , -1.64343352, -1.32485378],
#        ...,
#        [ 0.66261867, -1.09487797,  1.38580057,  0.67335521],
#        [ 0.66261867, -1.09487797,  0.28223854, -0.0121133 ],
#        [-1.18533666, -1.09487797, -1.16828402, -1.16384273]])

# %%
x.ndim
# Out:
# 2

# %%
x.mean()
# Out:
# 1.0286812205566422e-16

# %% [markdown]
# # Since the target column is continous we'll use LinearRegression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
(x_train,x_test,y_train,y_test)=train_test_split(x,y,random_state=45,test_size=.20)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
prd=lr.predict(x_test)
print('Coefficient - ',lr.coef_)
print('Score - ',lr.score(x_train,y_train))
# Out:
# Coefficient -  [14326.84957152  6773.58120431 10480.84495869 -6416.78022946]
# Score -  0.3889427229467741

# %%
print('Actual Result',y_test)
print('Predicted Result',prd)
# Out:
# Actual Result 22      93904
# 305    111350
# 85     132825
# 376     74856
# 113    104279
#         ...
# 164     88795
# 220    170000
# 194     90000
# 294    107300
# 117    117515
# Name: salary, Length: 71, dtype: int64
# Predicted Result [119680.59676532 118656.09568191 125443.38224713  83923.69865501
#  119351.12949466 124066.27247788 128764.55299197 117281.12707109
#   94623.9681618  127246.13636358 133665.53225209  99916.95549074
#  115112.68929618  98712.33224213 120026.05120846 118342.26533715
#  120757.32694259 100892.58308027 126485.93219585  89524.74529805
#   82483.04675963 126867.57199522 134018.79996966 107631.18651072
#   93862.41551258 125321.50575875  99875.55626728 121617.40383798
#   82763.81860135 112498.26008969 128731.56844459  86272.7030696
#  128015.372928   132662.80322281  85879.66872902 137366.75428107
#  114129.12996426 126485.93219585 137483.73900606 110925.00970527
#  134360.18014027 121682.70012159 131987.34447167 125266.82429924
# ...

# %%
print('error:')

print('mean absolute error: ',mean_absolute_error(y_test,prd))
print('mean squared error: ',mean_squared_error(y_test,prd))
print('root mean squared error: ',np.sqrt(mean_squared_error(y_test,prd)))
# Out:
# error:
# mean absolute error:  17514.155578400303
# mean squared error:  474877930.2764592
# root mean squared error:  21791.694066236778

# %% [markdown]
# # Model saving

# %%
import pickle
filename='salary.pkl'
pickle.dump(lr, open(filename,'wb'))

# %% [markdown]
# # Conclusion

# %%
a=np.array(y_test)
pred=np.array(lr.predict(x_test))
hscore=pd.DataFrame({'Actual':a,'Predicted':pred})
hscore
# Out:
#     Actual      Predicted
# 0    93904  119680.596765
# 1   111350  118656.095682
# 2   132825  125443.382247
# 3    74856   83923.698655
# 4   104279  119351.129495
# ..     ...            ...
# 66   88795   94563.840245
# 67  170000  127246.136364
# 68   90000  100482.644771
# 69  107300  119639.115106
# 70  117515  120958.895909
#
# [71 rows x 2 columns]
